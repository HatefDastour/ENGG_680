# %% [markdown]
# # Getting started with Matplotlib
#
# Matplotlib is a powerful Python library used to create a wide range of visualizations and plots. It has garnered widespread popularity for its role in facilitating data visualization and exploration tasks. To commence your exploration of Matplotlib's functionalities, adhere to these essential guidelines:

# %% [markdown]
# ## Import Matplotlib

# %% [markdown]
# In your Python script or Jupyter Notebook, start by importing Matplotlib:

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Create Basic Plots
#
# Here are examples of some basic types of plots you can create using Matplotlib:

# %% [markdown]
# ### Line Plot
# A line plot is useful for visualizing data points connected by lines, typically used for showing trends over time or continuous data. You can access the full description of the function [here](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html).

# %% [markdown]
# <font color='Blue'><b>Example - Simple:</b></font>

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Create a line plot
plt.plot(x, y, marker='o')

# Add labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line Plot Example')

# Display the plot
plt.show()

# %% [markdown]
# <font color='Red'><b>Remark:</b></font> This serves as a mere illustration of a line plot generated using matplotlib. Throughout this chapter, we will delve into the necessary stages to create more intricate plots.

# %% [markdown]
# ### Bar Plot
#
# A bar plot is useful for comparing data among different categories or groups. You can access the full description of the function [here](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html).

# %% [markdown]
# <font color='Blue'><b>Example - Simple:</b></font>

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Create a scatter plot
plt.scatter(x, y, marker='o', color='blue')

# Add labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot Example')

# Display the plot
plt.show()

# %% [markdown]
# ### Bar Plot
# A bar plot is useful for comparing data among different categories or groups.

# %% [markdown]
# <font color='Blue'><b>Example - Simple:</b></font>

# %%
import matplotlib.pyplot as plt

# Sample data
categories = ['Category A', 'Category B', 'Category C']
values = [10, 15, 7]

# Create a bar plot
plt.bar(categories, values, color='green')

# Add labels and title
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Plot Example')

# Display the plot
plt.show()

# %% [markdown]
# These are just a few examples of basic plots you can create using Matplotlib. The library provides extensive customization options for labels, titles, colors, and more. As you become more comfortable with Matplotlib, you can explore other types of plots, such as histograms, pie charts, and more advanced visualizations.
